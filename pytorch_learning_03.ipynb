# %% [markdown]
# <a href="https://colab.research.google.com/github/GubioGL/Aprendendo_pytorch/blob/main/pytorch_learning_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nessa parte iremos aprender sobre *Visão computacional* e *Redes Neurais Convolucionarias* com pytorch

# %% [markdown]
# # introdução a Imagem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Primeiro temos que converter/transformar o imagem em números(Tensor).
#
# Que vai ter altura x Largura x cor, a cor formada por qualquer imagem é dividida em azul, vermelho e verde RGB. Então ,
#
# Dimensão da imagem é : Altura x Largura x [vermelhor, azul,verde] =  Altura x Largura x 3.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Vamos baixar um imagem para ver com mais detalhes:

# %%
# !wget -O imagem.jpg https://www.qualviagem.com.br/wp-content/uploads/2015/06/Centro-Hist%C3%B3rico-Joao-Pessoa-PB-Foto-Cacio-Murilo-1024x682.jpg
# Out:
# --2024-01-24 13:16:25--  https://www.qualviagem.com.br/wp-content/uploads/2015/06/Centro-Hist%C3%B3rico-Joao-Pessoa-PB-Foto-Cacio-Murilo-1024x682.jpg
# Resolving www.qualviagem.com.br (www.qualviagem.com.br)... 104.21.77.241, 172.67.213.7, 2606:4700:3036::ac43:d507, ...
# Connecting to www.qualviagem.com.br (www.qualviagem.com.br)|104.21.77.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 259660 (254K) [image/jpeg]
# Saving to: ‘imagem.jpg’
#
# imagem.jpg          100%[===================>] 253.57K  --.-KB/s    in 0.008s
#
# 2024-01-24 13:16:26 (31.0 MB/s) - ‘imagem.jpg’ saved [259660/259660]

# %%
import imageio.v3 as io
import matplotlib.pyplot as plt

img = io.imread('imagem.jpg') # lendo a imagem
plt.imshow(img) # visualizando
img.shape
# Out:
# (682, 1024, 3)

# %% [markdown]
# Com essa imagem  podemos notar que 682 é a altura, 1024 largura e 3 são as cores, isso querdizer que temos as 3 cores.

# %%
img[0,0]
# Out:
# array([ 28,  85, 252], dtype=uint8)

# %% [markdown]
# Exemplo o pixel com  altura e largura = 0 temos 3 cores -> [ 28,  85, 252]

# %% [markdown]
# # algoritmo: CNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para saber mais sobre o CNN ver :https://www.ibm.com/br-pt/topics/convolutional-neural-networks
#
# ou https://www.youtube.com/watch?v=KuXjwB4LzSA&t=926s

# %% [markdown]
# ## 1. Obtendo os dados

# %% [markdown]
# Existe varias fontes disponivel, como o MNIST stands for Modified National Institute of Standards and Technology.
#
# Que é varias imagem com numero escritos na mão. No site do pytock vc encontra varia dataset para estudar.
#
#     Link : https://pytorch.org/vision/stable/datasets.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch as tc
from torch.utils.data import DataLoader
from  torchvision import datasets
from torchvision.transforms import ToTensor

train_dt = datasets.MNIST(
    root = "data", # De onde baixar os dados
    train = True, # Pega apenas os dados de treino
    download=True, # Baixar os dados para o disco local
    transform=ToTensor(), # Transforma a imagem do formato PIL para tensor
    #target_transform=None # you can transform labels as well
)

#Se vc tiver no colab pode importa direto.
#train_dt = DataLoader( "/content/sample_data/mnist_train_small.csv")
# Out:
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 88499443.88it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 13164061.49it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 109903402.30it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 8815607.94it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
train_dt.
# Out:
# '/content/sample_data/mnist_train_small.csv'
